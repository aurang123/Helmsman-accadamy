# %%
print("Hello world")
# Out:
# Hello world

# %%
1*4
# Out:
# 4

# %%
3+5
# Out:
# 8

# %%
10-7
# Out:
# 3

# %%
10/2
# Out:
# 5.0

# %%
print(int (input("Enter Number"))+5)
print(int (input("Enter Number"))-6)
print(int (input("Enter Number"))*6)
print(int (input("Enter Number"))/2)
# Out:
# Enter Number5
# 10
# Enter Number10
# 4
# Enter Number6
# 36
# Enter Number10
# 5.0

# %%
a=int (input("Enter Number"))
b=int (input("Enter Number"))
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# Enter Number5
# Enter Number8
# 13
# -3
# 40
# 0.625

# %%
a=10
b=5
c=a+b
print(c)
c=a-b
print(c)
c=a*b
print(c)
c=a/b
print(c)
# Out:
# 15
# 5
# 50
# 2.0
