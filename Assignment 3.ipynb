# %%
 # !pip install pandas

# %%
 
import pandas as pd
pd.__version__
# Out:
# '1.1.4'

# %%
from google.colab import files
uploaded = files.upload()
print(uploaded)
# Out:
#      <input type="file" id="files-63203445-04a0-4254-a408-657c14d9b011" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63203445-04a0-4254-a408-657c14d9b011">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving StudentsPerformance.csv to StudentsPerformance (3).csv
# ...

# %%
 
import pandas as pd
Studentperf=pd.read_csv("StudentsPerformance.csv")

# %%
 Studentperf.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
Studentperf.hist("writing score")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f02570af2b0>]],
#       dtype=object)

# %%
 import seaborn as sns

# %%
 Studentperf.plot.scatter("reading score","writing score", figsize = (9,3))

# %%
 
xData = [x for x in range(10)]
yData = [y for y in range(20)]
sns.lineplot(y="writing score" , x="reading score" , data=Studentperf)

# %%
 Studentperf.plot.scatter("math score","writing score", figsize = (9,3))

# %%
 
xData = [x for x in range(10)]
yData = [y for y in range(20)]
sns.lineplot(y="writing score",x="math score" , data=Studentperf)

# %%
 
from matplotlib import pyplot
size=(15,3)
ax=pyplot.subplots(figsize=size)
sns.countplot(x="parental level of education", data=Studentperf)
